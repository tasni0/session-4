# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib import font_manager as fm
import seaborn as sns
# %matplotlib inline

from datetime import datetime, timedelta #It's for time series

# %% [markdown]
# # Pyplot

# %%
x = [0,2,4,5,6,7,8,9,10]
y = [60,13,45,29,48,77,102,95,58]

# %%
plt.plot(x, y)
plt.show()

# %% [markdown]
# # Line Plot

# %%
experience = [1,3,4,5,7,8,10,12]

salary = [6500, 9280, 12050, 13200, 16672, 21000, 23965, 29793]

# %%
plt.plot(experience,salary)
plt.show()

# %% [markdown]
# # Adding a Title

# %%
plt.plot(experience,salary)
plt.title("Salary of Data Scientists by their experiences")
plt.show()

# %% [markdown]
# # Adding Labels to x and y

# %%
plt.plot(experience,salary)
plt.title("Salary of Data Scientists by their experiences")
plt.xlabel("Experience")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# # Plotting Multiple Graphs in One Graph

# %%
experience = [1,3,4,5,7,8,10,12]

data_scientists_salary = [6500, 9280, 12050, 13200, 16672, 21000, 23965, 29793]

software_engineers_salary = [9020, 12873, 15725, 18000, 19790, 20196, 25769,32000 ]

# %%
plt.plot(experience, data_scientists_salary)
plt.plot(experience, software_engineers_salary)

plt.title("Salary of Data Scientists and Software Engineers by their experiences")
plt.xlabel("Experience")
plt.ylabel("Salary")
plt.show()

# %%
plt.plot(experience,data_scientists_salary)
plt.plot(experience,software_engineers_salary)

plt.title("Salary of Data Scientists and Software Engineers by their experiences")
plt.xlabel("Experience")
plt.ylabel("Salary")

plt.legend(["Data Scientists","Software Engineers"])

plt.show()

# %%
plt.plot(experience,data_scientists_salary, label= "Data Scientists")
plt.plot(experience,software_engineers_salary, label= "Software Engineers" )

plt.title("Salary of Data Scientists and Software Engineers by their experiences")
plt.xlabel("Experience")
plt.ylabel("Salary")

plt.legend()

plt.show()

# %%
plt.plot(experience,data_scientists_salary, label= "Data Scientists")
plt.plot(experience,software_engineers_salary, label= "Software Engineers" )

plt.title("Salary of Data Scientists and Software Engineers by their experiences")
plt.xlabel("Experience")
plt.ylabel("Salary")

plt.legend(loc="lower right")

plt.show()

# %%
fmt = '[marker][line][color]'

# %%
plt.plot(experience,data_scientists_salary,color="r", label= "Data Scientists")
plt.plot(experience,software_engineers_salary, color="g", label= "Software Engineers" )

plt.title("Salary of Data Scientists and Software Engineers by their experiences")
plt.xlabel("Experience")
plt.ylabel("Salary")

plt.legend()

plt.show()

# %%
plt.plot(experience,data_scientists_salary,color="r", linestyle="--", label= "Data Scientists") #We can also make lines different
plt.plot(experience,software_engineers_salary, color="g",linestyle=':', label= "Software Engineers" )

plt.title("Salary of Data Scientists and Software Engineers by their experiences")
plt.xlabel("Experience")
plt.ylabel("Salary")

plt.legend()

plt.show()

# %%
#We can also add markers

plt.plot(experience,data_scientists_salary,color="r", linestyle="--",marker="o", label= "Data Scientists")
plt.plot(experience,software_engineers_salary, color="g",linestyle=':',marker=".", label= "Software Engineers" )

plt.title("Salary of Data Scientists and Software Engineers by their experiences")
plt.xlabel("Experience")
plt.ylabel("Salary")

plt.legend()

plt.show()

# %%
#We can also adjust line width by using linewidth argument.

plt.plot(experience,data_scientists_salary,color="r", linestyle="--",linewidth=6,marker="o", label= "Data Scientists")
plt.plot(experience,software_engineers_salary, color="g",linestyle=':',marker=".",linewidth=3, label= "Software Engineers" )

plt.title("Salary of Data Scientists and Software Engineers by their experiences")
plt.xlabel("Experience")
plt.ylabel("Salary")

plt.legend()

plt.show()

# %%
#We can also add grids by using grids argument

plt.plot(experience,data_scientists_salary,color="r", linestyle="--",linewidth=6,marker="o", label= "Data Scientists")
plt.plot(experience,software_engineers_salary, color="g",linestyle=':',marker=".",linewidth=6, label= "Software Engineers" )

plt.title("Salary of Data Scientists and Software Engineers by their experiences")
plt.xlabel("Experience")
plt.ylabel("Salary")

plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.plot(experience,data_scientists_salary,color="r", linestyle="--",linewidth=6,marker="o", label= "Data Scientists")
plt.plot(experience,software_engineers_salary, color="g",linestyle=':',marker=".",linewidth=6, label= "Software Engineers" )

plt.title("Salary of Data Scientists and Software Engineers by their experiences")
plt.xlabel("Experience")
plt.ylabel("Salary")

plt.legend()
plt.tight_layout()
plt.grid(True)
plt.show()

# %%
plt.stackplot(experience,data_scientists_salary, colors="g")

plt.title("Salary of Data Scientists by their experiences")
plt.xlabel("Experience")
plt.ylabel("Salary")


plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('dark_background')

plt.plot(experience,data_scientists_salary,color="r", linestyle="--",linewidth=6,marker="o", label= "Data Scientists")
plt.plot(experience,software_engineers_salary, color="g",linestyle=':',marker=".",linewidth=6, label= "Software Engineers" )

plt.title("Salary of Data Scientists and Software Engineers by their experiences")
plt.xlabel("Experience")
plt.ylabel("Salary")

plt.legend()
plt.tight_layout()
plt.grid(True)
plt.show()

# %%
plt.style.use('seaborn-dark')
# plt.style.use('dark_background')

plt.plot(experience,data_scientists_salary,color="r", linestyle="--",linewidth=6,marker="o", label= "Data Scientists")
plt.plot(experience,software_engineers_salary, color="g",linestyle=':',marker=".",linewidth=6, label= "Software Engineers" )

plt.title("Salary of Data Scientists and Software Engineers by their experiences")
plt.xlabel("Experience")
plt.ylabel("Salary")

plt.legend()
plt.tight_layout()
plt.grid(True)

plt.savefig("plot1.png")

plt.show()
# Out:
# C:\Users\kkhad\AppData\Local\Temp\ipykernel_6864\3222423231.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-dark')

# %% [markdown]
# # Bar Plot

# %%
x = ["A", "B", "C", "D"]
y = [3, 8, 1, 10]

# %%
plt.bar(x,y)
plt.show()

# %%
experience = [1,2,3,4,5,6,7,8]

data_scientists_salary = [6500, 9280, 12050, 13200, 16672, 21000, 23965, 29793]

# %%
plt.style.use('seaborn-paper')

plt.bar(experience,data_scientists_salary,color="b")

plt.title("Salary of Data Scientists")
plt.xlabel("Experience")
plt.ylabel("Salary")

plt.tight_layout()
plt.grid(False)

plt.show()
# Out:
# C:\Users\kkhad\AppData\Local\Temp\ipykernel_6864\1317790830.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-paper')

# %%
experience = [1,2,3,4,5,6,7,8]

data_scientists_salary = [6500, 9280, 12050, 13200, 16672, 21000, 23965, 29793]

software_engineers_salary = [9020, 12873, 15725, 18000, 19790, 20196, 25769,32000 ]

# %%
plt.style.use('tableau-colorblind10')

plt.bar(experience,data_scientists_salary,color="r", label= "Data Scientists")
plt.plot(experience,software_engineers_salary, color="g",label= "Software Engineers" )

plt.title("Salary of Data Scientists and Software Engineers by their experiences")
plt.xlabel("Experience")
plt.ylabel("Salary")

plt.legend()
plt.grid(False)

plt.show()

# %%
width = 0.2

plt.style.use('tableau-colorblind10')

plt.bar(experience,data_scientists_salary,color="m",width=width, label= "Data Scientists")

plt.title("Salary of Data Scientists by their experiences")
plt.xlabel("Experience")
plt.ylabel("Salary")

plt.legend()
plt.grid(False)

plt.show()

# %%
plt.style.use("fivethirtyeight")

plt.bar(experience,software_engineers_salary, color="g",linewidth=3,label= "Software Engineers" )
plt.bar(experience,data_scientists_salary,color="r",linewidth=3, label= "Data Scientists")

plt.title("Salary of Data Scientists and Software Engineers by their experiences")
plt.xlabel("Experience")
plt.ylabel("Salary")

plt.legend()
plt.grid(False)

plt.show()

# %%
experience_indexes = np.arange(len(experience))

# %%
experience_indexes
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7])

# %%
plt.style.use("fivethirtyeight")

width = 0.4

plt.bar(experience_indexes - width,software_engineers_salary, color="g",width=width,linewidth=3,label= "Software Engineers" )
plt.bar(experience_indexes + width,data_scientists_salary,color="r",linewidth=3,width=width, label= "Data Scientists")

plt.title("Salary of Data Scientists and Software Engineers by their experiences")
plt.xlabel("Experience")
plt.ylabel("Salary")

plt.legend()
plt.grid(False)

plt.show()

# %%
plt.style.use("fivethirtyeight")

width = 0.25

plt.bar(experience_indexes - width,software_engineers_salary, color="g",width=width,linewidth=3,label= "Software Engineers" )
plt.bar(experience_indexes+width,data_scientists_salary,color="r",linewidth=3,width=width, label= "Data Scientists")

plt.title("Salary of Data Scientists and Software Engineers by their experiences")
plt.xlabel("Experience")
plt.ylabel("Salary")

plt.xticks(ticks=experience_indexes, labels=experience)

plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# # Pie Chart

# %%
experience = [1,2,3,4,5,6,7,8]

data_scientists_salary = [6500, 9280, 12050, 13200, 16672, 21000, 23965, 29793]

software_engineers_salary = [9020, 12873, 15725, 18000, 19790, 20196, 25769,32000 ]

# %%
plt.title("Pie Chart Example")

slices = [60,40]

plt.pie(slices)

plt.tight_layout()

plt.show()

# %%
list_1 = [40,56,72,38,4]

plt.pie(list_1)

plt.show()

# %%
incomes = [40,56,72,38,4]

persons = ["Josh","Berkay","Maria","Michael","Anastacia"]

plt.pie(incomes,labels=persons)

plt.show()

# %%
incomes = [40,56,72,38,4]

persons = ["Josh","Berkay","Maria","Michael","Anastacia"]

plt.pie(incomes,labels=persons,startangle=180)

plt.show()

# %%
incomes = [40,56,72,38,4]

persons = ["Josh","Berkay","Maria","Michael","Anastacia"]

myexplode = [0,0.2, 0.3, 0, 0]

plt.pie(incomes,labels=persons,startangle=180,explode = myexplode)

plt.show()

# %%
plt.figure(figsize=(8,6))

plt.rcParams['font.size'] = 30

incomes = [40,56,72,38,4]

persons = ["Josh","Berkay","Maria","Michael","Anastacia"]

myexplode = [0,0.2, 0, 0, 0]

plt.pie(incomes,labels=persons,startangle=180,explode = myexplode)

plt.show()

# %%
plt.figure(figsize=(10,10))

plt.rcParams['font.size'] = 20

incomes = [40,56,72,38,4]

persons = ["Josh","Berkay","Maria","Michael","Anastacia"]

myexplode = [0,0.2, 0, 0, 0]

plt.pie(incomes,labels=persons,startangle=180,explode = myexplode,shadow=True)

plt.show()

# %%
plt.figure(figsize=(10,10))

plt.rcParams['font.size'] = 20

incomes = [40,56,72,38,4]

persons = ["Josh","Berkay","Maria","Michael","Anastacia"]

myexplode = [0,0.2, 0, 0, 0]

colors = ["black","g","y","hotpink","#4CAF70"]

plt.pie(incomes,labels=persons,startangle=180,explode = myexplode,shadow=True,colors=colors)

plt.show()

# %%
plt.figure(figsize=(7,7))

incomes = [40,56,72,38,4]

persons = ["Josh","Berkay","Maria","Michael","Anastacia"]

colors = ["black","g","y","hotpink","#4CAF70"]

plt.pie(incomes,labels=persons,colors=colors)
plt.legend()
plt.show()

# %%
plt.style.use("fivethirtyeight")

plt.figure(figsize=(7,7))

incomes = [40,56,72,38,4]

persons = ["Josh","Berkay","Maria","Michael","Anastacia"]

colors = ["black","g","y","hotpink","#4CAF70"]

plt.pie(incomes,labels=persons,colors=colors)
plt.legend(title="Persons")
plt.show()

# %%
plt.style.use("fivethirtyeight")

plt.figure(figsize=(7,7))

incomes = [40,56,72,38,4]

persons = ["Josh","Berkay","Maria","Michael","Anastacia"]

colors = ["black","g","y","hotpink","#4CAF70"]

plt.pie(incomes,labels=persons,colors=colors, autopct="%1.1f%%")
plt.legend(title="Persons")
plt.show()

# %%
fig = plt.figure(1, figsize=(6,6))

ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])

plt.title('Raining Hogs and Dogs')
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
fracs = [15,30,45, 10]

patches, texts, autotexts = ax.pie(fracs, labels=labels, autopct='%1.1f%%')

proptease = fm.FontProperties()
proptease.set_size('xx-small')

plt.setp(autotexts, fontproperties=proptease)
plt.setp(texts, fontproperties=proptease)

plt.show()

# %% [markdown]
# # Stack Plot

# %%
days = [1,2,3,4,5,6]

sleep = [6,7,5,8,6,7]
drinking_water =   [2,2,1,2,1,1]
work =  [5,7,10,8,6,9]
exercise=  [3,3,0,1,3,2]

# %%
plt.style.use("fivethirtyeight")


plt.plot([],[],color='green', label='sleep', linewidth=3)
plt.plot([],[],color='blue', label='drinking_water', linewidth=3)
plt.plot([],[],color='red', label='work', linewidth=3)
plt.plot([],[],color='orange', label='play', linewidth=3)

plt.stackplot(days, sleep, drinking_water, work, exercise, colors=['green','blue','red','orange'])

plt.xlabel('days')
plt.ylabel('activities')
plt.title('6 DAY ROUTINE STACK PLOT EXAMPLE')
plt.legend(loc="lower right")

plt.tight_layout()
plt.show()

# %%
stock1= [5,3,3,6,1,8,2,7,9]
stock2= [2,4,1,3,5,0,3,1,0]
stock3= [2,2,5,1,3,1,4,1,0]

days =[1,2,3,4,5,6,7,8,9]

# %%
stocks= ["stock1","stock2","stock3"]
colors = ["#F9CDAD", "#FC9D9A", "#83AF9B"]

plt.title("Stack Plot of Stock Rates")

plt.stackplot(days,stock1,stock2,stock3,labels=stocks,colors=colors)

plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Histograms

# %%
notes = [30,74,94,14,55,47,63,28,88,44,53,18,66,74,81]

# %%
plt.style.use("fivethirtyeight")

plt.hist(notes)

plt.show()

# %%
plt.style.use("fivethirtyeight")

plt.hist(notes,color="r")

plt.title("Notes")
plt.xlabel("Notes")
plt.ylabel("Person")

plt.tight_layout()
plt.grid(False)
plt.show()

# %%
plt.style.use("fivethirtyeight")

plt.hist(notes,color="r",edgecolor="black")

plt.title("Notes")
plt.xlabel("Notes")
plt.ylabel("Person")

plt.tight_layout()
plt.grid(False)
plt.show()

# %%
plt.style.use("fivethirtyeight")

plt.hist(notes,bins=5,color="g",edgecolor="black")

plt.title("Notes")
plt.xlabel("Notes")
plt.ylabel("Person")

plt.tight_layout()
plt.grid(False)
plt.show()

# %%
notes
# Out:
# [30, 74, 94, 14, 55, 47, 63, 28, 88, 44, 53, 18, 66, 74, 81]

# %%
plt.style.use("fivethirtyeight")

bins = [10,45,65,80,100]

plt.hist(notes,bins=bins,color="g",edgecolor="black")

plt.title("Notes")
plt.xlabel("Notes")
plt.ylabel("Person")

plt.tight_layout()
plt.grid(False)
plt.show()

# %%
x = np.random.normal(170, 10, 250)

plt.hist(x,color="gray",edgecolor="black")

plt.title("Normal Distribution")
plt.xlabel("Numbers")
plt.ylabel("Count")

plt.tight_layout()
plt.grid(False)
plt.show()

# %%
df = pd.read_csv("HRDataset_v14.csv")
df.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# 0  Michael Albert       22.0          LinkedIn          Exceeds
# 1      Simon Roup        4.0            Indeed      Fully Meets
# 2  Kissy Sullivan       20.0          LinkedIn      Fully Meets
# 3    Elijiah Gray       16.0            Indeed      Fully Meets
# 4  Webster Butler       39.0     Google Search      Fully Meets
#
#    EngagementSurvey EmpSatisfaction SpecialProjectsCount  \
# 0              4.60               5                    0
# 1              4.96               3                    6
# 2              3.02               3                    0
# 3              4.84               5                    0
# 4              5.00               4                    0
#
#   LastPerformanceReview_Date DaysLateLast30 Absences
# 0                  1/17/2019              0        1
# 1                  2/24/2016              0       17
# 2                  5/15/2012              0        3
# 3                   1/3/2019              0       15
# 4                   2/1/2016              0        2
#
# [5 rows x 36 columns]

# %%
plt.style.use("fivethirtyeight")

bins = [40000,55000,70000,85000,100000,120000]

plt.hist(df.Salary,bins=bins,color="blue",edgecolor="black")

plt.title("Salaries of Workers")
plt.xlabel("Salary")
plt.ylabel("Count")

plt.tight_layout()
plt.grid(False)
plt.show()

# %%
plt.style.use("fivethirtyeight")

bins = [40000,55000,70000,85000,100000,120000]

plt.hist(df.Salary,bins=bins,color="blue",edgecolor="black",log=True)

plt.title("Salaries of Workers")
plt.xlabel("Salary")
plt.ylabel("Count")

plt.tight_layout()
plt.grid(False)
plt.show()

# %%
plt.style.use("fivethirtyeight")

salary_median = df["Salary"].median()
salary_mean = df["Salary"].mean()
print(salary_median, salary_mean)
bins = [40000,55000,70000,85000,100000,120000]

plt.hist(df.Salary,bins=bins,color="blue",edgecolor="black")

plt.axvline(salary_median, color="gray", label="Salary Median", linewidth=3)
plt.axvline(salary_mean, color="green", label="Salary Mean", linewidth=3)

plt.legend()
plt.title("Salaries of Workers")
plt.xlabel("Salary")
plt.ylabel("Count")

plt.tight_layout()
plt.grid(False)
plt.show()
# Out:
# 62810.0 69020.6848874598

# %% [markdown]
# # Scatter Plots

# %%
first_exam_grades = [89, 90, 70, 89, 100, 80, 90, 100, 80, 34]
second_exam_grades = [30, 29, 49, 48, 100, 48, 38, 45, 20, 30]

# %%
plt.title("Exam Grades Scatter plot")

plt.scatter(first_exam_grades,second_exam_grades)

plt.tight_layout()
plt.xlabel("First Exam Grades")
plt.ylabel("Second Exam Grades")
plt.grid(True)
plt.show()

# %%
plt.title("Exam Grades Scatter plot")

plt.scatter(first_exam_grades,second_exam_grades,s=100,color="r")

plt.tight_layout()
plt.xlabel("First Exam Grades")
plt.ylabel("Second Exam Grades")
plt.grid(True)
plt.show()

# %%
plt.title("Exam Grades Scatter plot")

sizes = np.array([20,50,100,200,500,1000,60,90,10,300])

plt.scatter(first_exam_grades,second_exam_grades,s=sizes,color="r")

plt.tight_layout()
plt.xlabel("First Exam Grades")
plt.ylabel("Second Exam Grades")
plt.grid(True)
plt.show()

# %%
plt.title("Exam Grades Scatter plot")

plt.scatter(first_exam_grades,second_exam_grades,s=100,color="green",marker="d")

plt.tight_layout()
plt.xlabel("First Exam Grades")
plt.ylabel("Second Exam Grades")
plt.grid(True)
plt.show()

# %%
first_exam_grades = [89, 90, 70, 89, 100, 80, 90, 100, 80, 34]
first_study_hours = [6,8,3,9,9,1,4,2,2,5]

# %%
second_exam_grades = [30, 29, 49, 48, 100, 48, 38, 45, 20, 30]
second_study_hours = [2,7,1,5,3,3,2,6,3,2]

# %%
plt.title("Exam Grades Scatter plot")

plt.scatter(first_exam_grades,first_study_hours,s=100,color="green",marker="x")
plt.scatter(second_exam_grades,second_study_hours,s=100,color="red")

plt.tight_layout()
plt.xlabel("Exam Grades")
plt.ylabel("Study Hours")

plt.grid(True)
plt.show()

# %%
first_exam_grades = [89, 90, 70, 89, 100, 80, 90, 100, 80, 34]
second_exam_grades = [30, 29, 49, 48, 100, 48, 38, 45, 20, 30]
colors = [7, 5, 9, 7, 5, 7, 2, 5, 3, 7]
sizes = [209, 486, 381, 255, 191, 315, 185, 228, 174,538]

# %%
plt.title("Exam Grades Scatter plot")

plt.scatter(first_exam_grades,second_exam_grades,s=sizes,c=colors,cmap="Blues",edgecolor="black")

cbar = plt.colorbar()
cbar.set_label("Exam Grades")
plt.tight_layout()
plt.xlabel("First Exam Grades")
plt.ylabel("Second Exam Grades")

plt.grid(True)
plt.show()

# %% [markdown]
# # Contour(Level) Plots

# %%
x = [0,3,6,9,13,15,19,23,26,29,33,35,39,41,47,56] 
y = [5,8,13,16,17,20,25,26,30,33,37,39,41,44,48,59]

# %%
# Creating 2-D grid of features 
[X, Y] = np.meshgrid(x, y) 
  
fig, ax = plt.subplots(1, 1) 
  
Z = np.sqrt(X**2+Y**2)
  
# plots contour lines 
ax.contour(X, Y, Z) 
  
ax.set_title('Contour Plot') 
ax.set_xlabel('X values') 
ax.set_ylabel('Y values') 

plt.show()

# %%
# Creating 2-D grid of features 
[X, Y] = np.meshgrid(x, y) 
  
fig, ax = plt.subplots(1, 1) 
  
Z = np.sqrt(X**2+Y**2)
  
# plots contour lines 
ax.contourf(X, Y, Z) 
  
ax.set_title('Contour Plot') 
ax.set_xlabel('X values') 
ax.set_ylabel('Y values')

plt.show()

# %% [markdown]
# # Violin Plots

# %%
x = [0,3,6,9,13,15,19,23,26,29,33,35,39,41,47,56] 
y = [5,8,13,16,17,20,25,26,30,33,37,39,41,44,48,59]

# %%
data=[x,y]#First we will combine the collections

fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

bp = ax.violinplot(data)

plt.grid(False)
plt.title("Violin Plot")
plt.show()

# %% [markdown]
# # Plotting Time Series

# %%
dates = [
    datetime(2021, 3, 10),
    datetime(2021, 3, 13),
    datetime(2021, 3, 14),
    datetime(2021, 3, 15),
    datetime(2021, 3, 16),
    datetime(2021, 3, 17),
    datetime(2021, 3, 18),
    datetime(2021, 3, 19)
]

values = [0,3,4,7,5,3,5,6]

# %%
plt.title("Time Series")

plt.plot_date(dates, values)

plt.xticks(rotation='vertical')

plt.show()

# %%
plt.title("Time Series")

plt.plot_date(dates, values,linestyle="solid",marker = 'o',ms = 20, mfc = 'r',c="b" )

plt.xticks(rotation='vertical')
plt.xlabel("Dates")
plt.ylabel("Values")
plt.grid(False)

plt.show()
# Out:
# C:\Users\kkhad\AppData\Local\Temp\ipykernel_6864\499255847.py:3: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot_date(dates, values,linestyle="solid",marker = 'o',ms = 20, mfc = 'r',c="b" )

# %% [markdown]
# # Box Plot

# %%
Salaries = [6900,7500,4700,11997,22000,16550,9655,8670,15090,29000,7600,14980,1250]

# %%
plt.boxplot(Salaries)

plt.title("Box Plot of Salaries")

plt.ylabel("Salaries")

plt.show()

# %%
plt.boxplot(Salaries, notch=True)

plt.title("Box Plot of Salaries")

plt.ylabel("Salaries")

plt.show()

# %%
green_diamond = dict(markerfacecolor='g', marker='D')

plt.boxplot(Salaries, notch=True, flierprops=green_diamond)

plt.title("Box Plot of Salaries")

plt.ylabel("Salaries")

plt.show()

# %%
plt.boxplot(Salaries, notch=True, showfliers=False)

plt.title("Box Plot of Salaries")

plt.ylabel("Salaries")

plt.show()

# %%
plt.boxplot(Salaries, notch=True, showfliers=False, vert=False)

plt.title("Box Plot of Salaries")

plt.xlabel("Salaries")

plt.show()

# %% [markdown]
# # Heatmap

# %%
data = np.random.random(( 6 , 6 )) 
data
# Out:
# array([[0.95707482, 0.64679646, 0.23767767, 0.81476811, 0.92613433,
#         0.05182709],
#        [0.83464812, 0.02937909, 0.77841695, 0.75481364, 0.89103062,
#         0.1517932 ],
#        [0.17202333, 0.94199091, 0.54025057, 0.65004609, 0.24921569,
#         0.88091537],
#        [0.54879419, 0.17450587, 0.68513701, 0.47097758, 0.92425767,
#         0.83951027],
#        [0.60021305, 0.01646186, 0.41283684, 0.26041011, 0.1398496 ,
#         0.5158722 ],
#        [0.65774854, 0.30846915, 0.7371235 , 0.62037785, 0.42209739,
#         0.77582789]])

# %%
plt.imshow( data , cmap = 'autumn' ) 
  
plt.title( "2-D Heat Map" ) 
plt.show()

# %%
sns.heatmap( data , linewidth = 0.5 , cmap = 'coolwarm' ) 
  
plt.title( "2-D Heat Map" ) 
plt.show()

# %%
plt.pcolormesh( data , cmap = 'summer' ) 
  
plt.title( '2-D Heat Map' ) 
plt.show()

# %%
flights = sns.load_dataset("flights")

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
import pandas as pd

# Assuming 'flights' is your DataFrame with columns 'month', 'year', and 'passengers'
# Replace this with your actual DataFrame
data = {'month': ['Jan', 'Jan', 'Feb', 'Feb', 'Mar', 'Mar'],
        'year': [2020, 2021, 2020, 2021, 2020, 2021],
        'passengers': [100, 120, 150, 180, 200, 220]}
flights = pd.DataFrame(data)

# Pivot the DataFrame
flights_pivoted = flights.pivot(index='month', columns='year', values='passengers')

flights_pivoted
# Out:
# year   2020  2021
# month
# Feb     150   180
# Jan     100   120
# Mar     200   220

# %%
flights
# Out:
#   month  year  passengers
# 0   Jan  2020         100
# 1   Jan  2021         120
# 2   Feb  2020         150
# 3   Feb  2021         180
# 4   Mar  2020         200
# 5   Mar  2021         220

# %%
sns.heatmap(flights_pivoted , linewidth = 0.5 , cmap = 'YlGn' ) 
  
plt.title( "Flights Heat Map" ) 
plt.show()
